# %%
import pandas as pd

df=pd.read_parquet("for_vis.parquet")
df1=pd.read_parquet("staging.parquet")
print(df)
# Out:
#              time  temperature_2m_max  temperature_2m_min  \
# 0      2020-01-01                14.9                 6.6
# 1      2020-01-02                13.4                 7.6
# 2      2020-01-03                 9.6                 8.1
# 3      2020-01-04                10.1                 8.0
# 4      2020-01-05                11.2                 7.1
# ...           ...                 ...                 ...
# 503695 2026-04-14                16.6                 8.8
# 503696 2026-04-15                16.9                 7.8
# 503697 2026-04-16                18.5                 5.2
# 503698 2026-04-17                19.5                 7.2
# 503699 2026-04-18                20.0                 8.0
#
#         temperature_2m_mean  precipitation_sum  rain_sum  snowfall_sum  \
# 0                      10.0                5.2       5.2           0.0
# 1                      10.1               13.0      13.0           0.0
# ...
